# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
import os
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
#path to source CSV
file_path_boroughs = os.path.join("actualApp/data/Transformation","boroughs_id.csv")
file_path_host = os.path.join("actualApp/data/Transformation","host_id.csv")
file_path_lisiting = os.path.join("actualApp/data/Transformation","listings-detailed-cleaned.csv")
file_path_neighbourhood = os.path.join("actualApp/data/Transformation","neighbourhood_id.csv")
file_path_room_type = os.path.join("actualApp/data/Transformation","room_type_id.csv")
file_path_rates_dayofweek = os.path.join("actualApp/data/Transformation","rates_dayofweek.csv")
file_path_rates_monthly = os.path.join("actualApp/data/Transformation","rates_monthly.csv")

# %%
#read country csv
boroughs_data = pd.read_csv(file_path_boroughs)
host_data = pd.read_csv(file_path_host)
listing_data = pd.read_csv(file_path_lisiting)
neighbourhood_data = pd.read_csv(file_path_neighbourhood)
room_type_data = pd.read_csv(file_path_room_type)
dayofweek_data = pd.read_csv(file_path_rates_dayofweek)
rates_monthly_data = pd.read_csv(file_path_rates_monthly)

#boroughs_data id as the index
boroughs_data = boroughs_data.set_index(['borough_id'])
host_data = host_data.set_index(['host_id'])
listing_data = listing_data.set_index(['id'])
neighbourhood_data = neighbourhood_data.set_index(['neighbourhood_id'])
room_type_data = room_type_data.set_index(['room_type_id'])
#dayofweek_data = dayofweek_data.set_index(['listing_id'])
#rates_monthly_data = rates_monthly_data.set_index(['listing_id'])
# Out:
# C:\Users\Hilla\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(listing_data)
# Out:
# ['listing_url',
#  'name',
#  'description',
#  'picture_url',
#  'host_id',
#  'host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'superhost',
#  'host_listings_count',
#  'host_identity_verified',
#  'neighbourhood_id',
#  'borough_id',
#  'latitude',
#  'longitude',
#  'room_type_id',
#  'accommodates',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'reviews_per_month']

# %% [markdown]
# ### Create database connection

# %%
#create connection
engine = create_engine(f'postgres://ablekwsj:scRNnW0ztSKbX4PP5NQnVJq_uoU0iZ-O@ziggy.db.elephantsql.com:5432/ablekwsj')
connection = engine.connect()
print("Connected!")
# Out:
# Connected!

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['host_id',
#  'listing_master',
#  'neighbourhood_id',
#  'boroughs_Id',
#  'room_type_id',
#  'rates_monthly',
#  'rates_weekOfDay']

# %%
#load boroughs_id
#boroughs_data.to_sql(name='boroughs_Id', con=engine, if_exists='append', index=True)

# %%
#Load host_id
#host_data.to_sql(name='host_id', con=engine, if_exists='append', index=True)

# %%
#load listings-detailed-cleaned
listing_data.to_sql(name='listing_master', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "review_scores_checkin" of relation "listing_master" does not exist
# LINE 1: ...eview_scores_accuracy, review_scores_cleanliness, review_sco...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-7-5c0cbbb44635> in <module>
#       1 #load listings-detailed-cleaned
# ----> 2 listing_data.to_sql(name='listing_master', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980             raise exc.ObjectNotExecutableError(object_)
#     981         else:
# --> 982             return meth(self, multiparams, params)
#     983
#     984     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1099             distilled_params,
#    1100             compiled_sql,
# -> 1101             distilled_params,
#    1102         )
#    1103         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248         except BaseException as e:
#    1249             self._handle_dbapi_exception(
# -> 1250                 e, statement, parameters, cursor, context
#    1251             )
#    1252
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1474                 util.raise_from_cause(newraise, exc_info)
#    1475             elif should_wrap:
# -> 1476                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1477             else:
#    1478                 util.reraise(*exc_info)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1224                 if not evt_handled:
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#    1228             elif not parameters and context.no_parameters:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "review_scores_checkin" of relation "listing_master" does not exist
# LINE 1: ...eview_scores_accuracy, review_scores_cleanliness, review_sco...
#                                                              ^
#
# [SQL: INSERT INTO listing_master (id, listing_url, name, description, picture_url, host_id, host_since, host_response_time, host_response_rate, host_acceptance_rate, superhost, host_listings_count, host_identity_verified, neighbourhood_id, borough_id, latitude, longitude, room_type_id, accommodates, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, has_availability, availability_30, availability_60, availability_90, availability_365, number_of_reviews, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, instant_bookable, reviews_per_month) VALUES (%(id)s, %(listing_url)s, %(name)s, %(description)s, %(picture_url)s, %(host_id)s, %(host_since)s, %(host_response_time)s, %(host_response_rate)s, %(host_acceptance_rate)s, %(superhost)s, %(host_listings_count)s, %(host_identity_verified)s, %(neighbourhood_id)s, %(borough_id)s, %(latitude)s, %(longitude)s, %(room_type_id)s, %(accommodates)s, %(bathrooms_text)s, %(bedrooms)s, %(beds)s, %(amenities)s, %(price)s, %(minimum_nights)s, %(maximum_nights)s, %(has_availability)s, %(availability_30)s, %(availability_60)s, %(availability_90)s, %(availability_365)s, %(number_of_reviews)s, %(review_scores_rating)s, %(review_scores_accuracy)s, %(review_scores_cleanliness)s, %(review_scores_checkin)s, %(review_scores_communication)s, %(review_scores_location)s, %(review_scores_value)s, %(instant_bookable)s, %(reviews_per_month)s)]
# [parameters: ({'id': 2595, 'listing_url': 'https://www.airbnb.com/rooms/2595', 'name': 'Skylit Midtown Castle', 'description': 'Beautiful, spacious skylit studio in the heart of Midtown, Manhattan. <br /><br />STUNNING SKYLIT STUDIO / 1 BED + SINGLE / FULL BATH / FULL KITCHEN  ... (702 characters truncated) ... h, newly renovated kitchen, air conditioning/heat, high speed WiFi Internet, and Apple TV.<br />- Centrally located in the heart of Midtown Manhattan', 'picture_url': 'https://a0.muscache.com/pictures/f0813a11-40b2-489e-8217-89a2e1637830.jpg', 'host_id': 2845, 'host_since': '2008-09-09', 'host_response_time': 'within a few hours', 'host_response_rate': '0.92', 'host_acceptance_rate': '0.25', 'superhost': False, 'host_listings_count': 6.0, 'host_identity_verified': True, 'neighbourhood_id': 116, 'borough_id': 4, 'latitude': 40.75362, 'longitude': -73.98376999999999, 'room_type_id': 2, 'accommodates': 2, 'bathrooms_text': '1 bath', 'bedrooms': None, 'beds': 1.0, 'amenities': '["Hot water", "Extra pillows and blankets", "Oven", "Cleaning before checkout", "Iron", "Long term stays allowed", "TV", "Baking sheet", "Wifi", "Ref ... (232 characters truncated) ... es", "Bed linens", "Hair dryer", "Coffee maker", "Cooking basics", "Luggage dropoff allowed", "Stove", "Hangers", "Kitchen", "Carbon monoxide alarm"]', 'price': '$175.00', 'minimum_nights': 30, 'maximum_nights': 1125, 'has_availability': 'TRUE', 'availability_30': 30, 'availability_60': 60, 'availability_90': 90, 'availability_365': 365, 'number_of_reviews': 48, 'review_scores_rating': 94.0, 'review_scores_accuracy': 9.0, 'review_scores_cleanliness': 9.0, 'review_scores_checkin': 10.0, 'review_scores_communication': 10.0, 'review_scores_location': 10.0, 'review_scores_value': 9.0, 'instant_bookable': False, 'reviews_per_month': 0.36}, {'id': 3831, 'listing_url': 'https://www.airbnb.com/rooms/3831', 'name': 'Whole flr w/private bdrm, bath & kitchen(pls read)', 'description': 'Enjoy 500 s.f. top floor in 1899 brownstone, w/ wood & ceramic flooring throughout, roomy bdrm, & upgraded kitchen & bathroom.\xa0 This space is uniq ... (713 characters truncated) ... oor for our guests consists of a sizable bedroom, full bath and eat-in kitchen for your exclusive use - you get the amenities of a private apartment ', 'picture_url': 'https://a0.muscache.com/pictures/e49999c2-9fd5-4ad5-b7cc-224deac989aa.jpg', 'host_id': 4869, 'host_since': '2008-12-07', 'host_response_time': 'within an hour', 'host_response_rate': '0.95', 'host_acceptance_rate': '0.93', 'superhost': False, 'host_listings_count': 1.0, 'host_identity_verified': True, 'neighbourhood_id': 64, 'borough_id': 3, 'latitude': 40.685140000000004, 'longitude': -73.95976, 'room_type_id': 2, 'accommodates': 3, 'bathrooms_text': '1 bath', 'bedrooms': 1.0, 'beds': 3.0, 'amenities': '["Hot water", "Shampoo", "Baby safety gates", "Oven", "Extra pillows and blankets", "Pack \\u2019n Play/travel crib", "Iron", "Long term stays allowe ... (305 characters truncated) ... hair", "Hair dryer", "Coffee maker", "Cooking basics", "Cable TV", "Luggage dropoff allowed", "Stove", "Hangers", "Kitchen", "Carbon monoxide alarm"]', 'price': '$74.00', 'minimum_nights': 1, 'maximum_nights': 730, 'has_availability': 'TRUE', 'availability_30': 12, 'availability_60': 31, 'availability_90': 61, 'availability_365': 307, 'number_of_reviews': 375, 'review_scores_rating': 89.0, 'review_scores_accuracy': 9.0, 'review_scores_cleanliness': 9.0, 'review_scores_checkin': 9.0, 'review_scores_communication': 9.0, 'review_scores_location': 10.0, 'review_scores_value': 10.0, 'instant_bookable': False, 'reviews_per_month': 4.97}, {'id': 5121, 'listing_url': 'https://www.airbnb.com/rooms/5121', 'name': 'BlissArtsSpace!', 'description': "<b>The space</b><br />HELLO EVERYONE AND THANKS FOR VISITING BLISS ART SPACE! <br /><br />Thank you all for your support. I've traveled a lot in the  ... (702 characters truncated) ... t me know and I’ll give you the monthly rate for tha ...
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
#load neighbourhood_id
#neighbourhood_data.to_sql(name='neighbourhood_id', con=engine, if_exists='append', index=True)

# %%
#load rates_dayofweek
#dayofweek_data.to_sql(name='rates_dayofweek', con=engine, if_exists='append', index=True)

# %%
#load rates_monthly
#rates_monthly_data.to_sql(name='rates_monthly', con=engine, if_exists='append', index=True)

# %%
#load room_type_id
#room_type_data.to_sql(name='room_type_id', con=engine, if_exists='append', index=True)

# %%
#close connection
#connection.close

# %% [markdown]
# ### Load DataFrames into database
