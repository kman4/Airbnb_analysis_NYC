# %%
# Dependencies
# --------------------------------------------------------------------------------------------------------

# To view pandas Dataframe
import pandas as pd

# SQL Alchemy to connect to Postgres and hide username and password to prevent others to use your access
import os
import pandas as pd
import datetime as dt
from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)
from flask_sqlalchemy import SQLAlchemy
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from config import username, password
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/AIRBNB')
connection = engine.connect()
import numpy as numpy

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['boroughs_Id',
#  'rates_yearly',
#  'neighbourhood_id',
#  'room_type_id',
#  'listing_master']

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
listing_df =pd.read_sql('SELECT * FROM "listing_master"', connection)

# %%
borough_df =pd.read_sql('SELECT * FROM "boroughs_Id"', connection)
neigh_df =pd.read_sql('SELECT * FROM "neighbourhood_id"', connection)

# %%
rates_df = pd.read_sql('SELECT * FROM "rates_yearly"', connection)

# %%
roomtype_df =pd.read_sql('SELECT * FROM "room_type_id"', connection)
roomtype_df
# Out:
#    roomtype_id        room_type
# 0            1  Entire home/apt
# 1            2     Private room
# 2            3       Hotel room
# 3            4      Shared room

# %% [markdown]
# ## Borough json ##

# %%
borough_df['borough'].to_json(orient="records")

# %% [markdown]
# ## Listing Json ##

# %%
merge = pd.merge(listing_df, borough_df, on = "borough_id", how = "inner")
merge
# Out:
#              id  neighborhood_id  borough_id  latitude  longitude  \
# 0          2595              115           3  40.75362   -73.9838
# 1          5178              115           3  40.76468   -73.9832
# 2          5203              127           3  40.80178   -73.9672
# 3          6872              102           3  40.80139   -73.9424
# 4          6990              102           3  40.78962   -73.9480
# ...         ...              ...         ...       ...        ...
# 36918  46815223               44           1  40.84743   -73.8640
# 36919  46879720               35           1  40.80738   -73.9304
# 36920  46891041               48           1  40.87811   -73.8636
# 36921  46897706               22           1  40.81938   -73.9179
# 36922  46927112               44           1  40.84385   -73.8632
#
#        roomtype_id  price  number_of_reviews superhost    borough
# 0                1    175                 48         0  Manhattan
# 1                2     65                474         0  Manhattan
# 2                2     75                118         0  Manhattan
# 3                2     65                  0         0  Manhattan
# 4                2     62                233         0  Manhattan
# ...            ...    ...                ...       ...        ...
# 36918            1     70                  0         0      Bronx
# 36919            1    500                  0         0      Bronx
# 36920            1    159                  0         0      Bronx
# 36921            1     85                  0         0      Bronx
# 36922            2     40                  0         0      Bronx
#
# [36923 rows x 10 columns]

# %%
merge1 = pd.merge(merge, neigh_df, on = "neighborhood_id", how = "inner")
merge1
# Out:
#              id  neighborhood_id  borough_id  latitude  longitude  \
# 0          2595              115           3  40.75362   -73.9838
# 1          5178              115           3  40.76468   -73.9832
# 2         59855              115           3  40.75890   -73.9699
# 3         61509              115           3  40.75749   -73.9690
# 4        235951              115           3  40.75348   -73.9707
# ...         ...              ...         ...       ...        ...
# 36918  46927112               44           1  40.84385   -73.8632
# 36919  26810987                5           1  40.81511   -73.8486
# 36920  40582472                5           1  40.82244   -73.8518
# 36921  38187517               47           1  40.84532   -73.8832
# 36922  46758269               12           1  40.84808   -73.8208
#
#        roomtype_id  price  number_of_reviews superhost    borough  \
# 0                1    175                 48         0  Manhattan
# 1                2     65                474         0  Manhattan
# 2                1    250                 82         1  Manhattan
# 3                1    110                 92         0  Manhattan
# 4                1    125                145         1  Manhattan
# ...            ...    ...                ...       ...        ...
# 36918            2     40                  0         0      Bronx
# 36919            1     65                 53         1      Bronx
# 36920            1     71                 75         1      Bronx
# 36921            2     65                  1         0      Bronx
# 36922            2     68                  0         0      Bronx
#
#       neighbourhood
# 0           Midtown
# 1           Midtown
# 2           Midtown
# 3           Midtown
# 4           Midtown
# ...             ...
# 36918      Van Nest
# 36919   Castle Hill
# 36920   Castle Hill
# 36921    West Farms
# 36922  Country Club
#
# [36923 rows x 11 columns]

# %%
listing_count= pd.DataFrame(merge1.groupby("borough")["id"].count().reset_index())
listing_count
# Out:
#          borough     id
# 0          Bronx    937
# 1       Brooklyn  14439
# 2      Manhattan  16642
# 3         Queens   4629
# 4  Staten Island    276

# %%
listing_count.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","id":937},{"borough":"Brooklyn","id":14439},{"borough":"Manhattan","id":16642},{"borough":"Queens","id":4629},{"borough":"Staten Island","id":276}]'

# %% [markdown]
# ## Neighbourhood Count ##

# %%
neigh_df.to_csv("neigh.csv")

# %%
# Study data files
neigh_borough = "neigh.csv"
# Read the mouse data and the study results
neigh_count = pd.read_csv(neigh_borough)

# %%
neigh_count
# Out:
#            borough  neighbourhood
# 0            Bronx       Allerton
# 1            Bronx     Baychester
# 2            Bronx        Belmont
# 3            Bronx      Bronxdale
# 4            Bronx    Castle Hill
# ..             ...            ...
# 225  Staten Island    Tottenville
# 226  Staten Island  West Brighton
# 227  Staten Island    Westerleigh
# 228  Staten Island    Willowbrook
# 229  Staten Island        Woodrow
#
# [230 rows x 2 columns]

# %%
neigh_count.to_csv("neigh.count.csv")

# %%
# Study data files
xyz = "neigh.count.csv"
# Read the mouse data and the study results
neigh_count = pd.read_csv(xyz)
neigh_count
# Out:
#            borough  neighbourhood
# 0            Bronx       Allerton
# 1            Bronx     Baychester
# 2            Bronx        Belmont
# 3            Bronx      Bronxdale
# 4            Bronx    Castle Hill
# ..             ...            ...
# 225  Staten Island    Tottenville
# 226  Staten Island  West Brighton
# 227  Staten Island    Westerleigh
# 228  Staten Island    Willowbrook
# 229  Staten Island        Woodrow
#
# [230 rows x 2 columns]

# %%
neigh_count= pd.DataFrame(neigh_count.groupby("borough")["neighbourhood"].count().reset_index())
neigh_count
# Out:
#          borough  neighbourhood
# 0          Bronx             49
# 1       Brooklyn             48
# 2      Manhattan             32
# 3         Queens             53
# 4  Staten Island             48

# %%
neigh_count.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","neighbourhood":49},{"borough":"Brooklyn","neighbourhood":48},{"borough":"Manhattan","neighbourhood":32},{"borough":"Queens","neighbourhood":53},{"borough":"Staten Island","neighbourhood":48}]'

# %%
review_count= pd.DataFrame(merge1.groupby("borough")["number_of_reviews"].sum().reset_index())
review_count
# Out:
#          borough  number_of_reviews
# 0          Bronx              28303
# 1       Brooklyn             368528
# 2      Manhattan             315373
# 3         Queens             133022
# 4  Staten Island              10734

# %% [markdown]
# ## Review Count ##

# %%
review_count.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","number_of_reviews":28303},{"borough":"Brooklyn","number_of_reviews":368528},{"borough":"Manhattan","number_of_reviews":315373},{"borough":"Queens","number_of_reviews":133022},{"borough":"Staten Island","number_of_reviews":10734}]'

# %% [markdown]
# ## Rates by Year ##

# %%
rates_df
# Out:
#     rates_id  borough_id  year  price
# 0          1           1  2017     78
# 1          2           1  2018     75
# 2          3           1  2019     82
# 3          4           1  2020     88
# 4          5           1  2021     83
# 5          6           2  2017    140
# 6          7           2  2018    141
# 7          8           2  2019    125
# 8          9           2  2020    127
# 9         10           2  2021    124
# 10        11           3  2017    198
# 11        12           3  2018    226
# 12        13           3  2019    188
# 13        14           3  2020    202
# 14        15           3  2021    184
# 15        16           4  2017    111
# 16        17           4  2018    107
# 17        18           4  2019    103
# 18        19           4  2020    105
# 19        20           4  2021    115
# 20        21           5  2017     86
# 21        22           5  2018    101
# 22        23           5  2019     95
# 23        24           5  2020     99
# 24        25           5  2021    101

# %%
borough_df
# Out:
#    borough_id        borough
# 0           1          Bronx
# 1           2       Brooklyn
# 2           3      Manhattan
# 3           4         Queens
# 4           5  Staten Island

# %% [markdown]
# ## Line Chart ##

# %%
rates_merge = pd.merge(rates_df, borough_df, on = "borough_id", how = "inner")
rates_merge
# Out:
#     rates_id  borough_id  year  price        borough
# 0          1           1  2017     78          Bronx
# 1          2           1  2018     75          Bronx
# 2          3           1  2019     82          Bronx
# 3          4           1  2020     88          Bronx
# 4          5           1  2021     83          Bronx
# 5          6           2  2017    140       Brooklyn
# 6          7           2  2018    141       Brooklyn
# 7          8           2  2019    125       Brooklyn
# 8          9           2  2020    127       Brooklyn
# 9         10           2  2021    124       Brooklyn
# 10        11           3  2017    198      Manhattan
# 11        12           3  2018    226      Manhattan
# 12        13           3  2019    188      Manhattan
# 13        14           3  2020    202      Manhattan
# 14        15           3  2021    184      Manhattan
# 15        16           4  2017    111         Queens
# 16        17           4  2018    107         Queens
# 17        18           4  2019    103         Queens
# 18        19           4  2020    105         Queens
# 19        20           4  2021    115         Queens
# 20        21           5  2017     86  Staten Island
# 21        22           5  2018    101  Staten Island
# 22        23           5  2019     95  Staten Island
# 23        24           5  2020     99  Staten Island
# 24        25           5  2021    101  Staten Island

# %%
rates_merge = rates_merge[['borough', 'year', 'price']]

# %%
rates_merge.rename(columns = {'price':'rates'})
# Out:
#           borough  year  rates
# 0           Bronx  2017     78
# 1           Bronx  2018     75
# 2           Bronx  2019     82
# 3           Bronx  2020     88
# 4           Bronx  2021     83
# 5        Brooklyn  2017    140
# 6        Brooklyn  2018    141
# 7        Brooklyn  2019    125
# 8        Brooklyn  2020    127
# 9        Brooklyn  2021    124
# 10      Manhattan  2017    198
# 11      Manhattan  2018    226
# 12      Manhattan  2019    188
# 13      Manhattan  2020    202
# 14      Manhattan  2021    184
# 15         Queens  2017    111
# 16         Queens  2018    107
# 17         Queens  2019    103
# 18         Queens  2020    105
# 19         Queens  2021    115
# 20  Staten Island  2017     86
# 21  Staten Island  2018    101
# 22  Staten Island  2019     95
# 23  Staten Island  2020     99
# 24  Staten Island  2021    101

# %%
rates_merge.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","year":2017,"price":78},{"borough":"Bronx","year":2018,"price":75},{"borough":"Bronx","year":2019,"price":82},{"borough":"Bronx","year":2020,"price":88},{"borough":"Bronx","year":2021,"price":83},{"borough":"Brooklyn","year":2017,"price":140},{"borough":"Brooklyn","year":2018,"price":141},{"borough":"Brooklyn","year":2019,"price":125},{"borough":"Brooklyn","year":2020,"price":127},{"borough":"Brooklyn","year":2021,"price":124},{"borough":"Manhattan","year":2017,"price":198},{"borough":"Manhattan","year":2018,"price":226},{"borough":"Manhattan","year":2019,"price":188},{"borough":"Manhattan","year":2020,"price":202},{"borough":"Manhattan","year":2021,"price":184},{"borough":"Queens","year":2017,"price":111},{"borough":"Queens","year":2018,"price":107},{"borough":"Queens","year":2019,"price":103},{"borough":"Queens","year":2020,"price":105},{"borough":"Queens","year":2021,"price":115},{"borough":"Staten Island","year":2017,"price":86},{"borough":"Staten Island","year":2018,"price":101},{"borough":"Staten Island","year":2019,"price":95},{"borough":"Staten Island","year":2020,"price":99},{"borough":"Staten Island","year":2021,"price":101}]'

# %% [markdown]
# ## Pie Chart ##

# %%
merge2
# Out:
#              id  neighborhood_id  borough_id  latitude  longitude  \
# 0          2595              115           3  40.75362   -73.9838
# 1         59855              115           3  40.75890   -73.9699
# 2         61509              115           3  40.75749   -73.9690
# 3        235951              115           3  40.75348   -73.9707
# 4        271694              115           3  40.75282   -73.9732
# ...         ...              ...         ...       ...        ...
# 36918  35540417              165           4  40.75331   -73.9350
# 36919  38481169              165           4  40.75331   -73.9350
# 36920  15974141              131           4  40.76839   -73.9311
# 36921  35904939              132           4  40.76273   -73.7604
# 36922  42065563               26           1  40.81513   -73.9160
#
#        roomtype_id  price  number_of_reviews superhost    borough  \
# 0                1    175                 48         0  Manhattan
# 1                1    250                 82         1  Manhattan
# 2                1    110                 92         0  Manhattan
# 3                1    125                145         1  Manhattan
# 4                1    125                 19         0  Manhattan
# ...            ...    ...                ...       ...        ...
# 36918            3    150                 17         0     Queens
# 36919            3    120                  8         0     Queens
# 36920            3    100                  1         0     Queens
# 36921            3    118                  1         0     Queens
# 36922            3      0                  0         0      Bronx
#
#           neighbourhood        room_type
# 0               Midtown  Entire home/apt
# 1               Midtown  Entire home/apt
# 2               Midtown  Entire home/apt
# 3               Midtown  Entire home/apt
# 4               Midtown  Entire home/apt
# ...                 ...              ...
# 36918  Long Island City       Hotel room
# 36919  Long Island City       Hotel room
# 36920           Astoria       Hotel room
# 36921           Bayside       Hotel room
# 36922        Mott Haven       Hotel room
#
# [36923 rows x 12 columns]

# %%
merge2 = pd.merge(merge1, roomtype_df, on = "roomtype_id", how = "inner")
merge2
# Out:
#              id  neighborhood_id  borough_id  latitude  longitude  \
# 0          2595              115           3  40.75362   -73.9838
# 1         59855              115           3  40.75890   -73.9699
# 2         61509              115           3  40.75749   -73.9690
# 3        235951              115           3  40.75348   -73.9707
# 4        271694              115           3  40.75282   -73.9732
# ...         ...              ...         ...       ...        ...
# 36918  35540417              165           4  40.75331   -73.9350
# 36919  38481169              165           4  40.75331   -73.9350
# 36920  15974141              131           4  40.76839   -73.9311
# 36921  35904939              132           4  40.76273   -73.7604
# 36922  42065563               26           1  40.81513   -73.9160
#
#        roomtype_id  price  number_of_reviews superhost    borough  \
# 0                1    175                 48         0  Manhattan
# 1                1    250                 82         1  Manhattan
# 2                1    110                 92         0  Manhattan
# 3                1    125                145         1  Manhattan
# 4                1    125                 19         0  Manhattan
# ...            ...    ...                ...       ...        ...
# 36918            3    150                 17         0     Queens
# 36919            3    120                  8         0     Queens
# 36920            3    100                  1         0     Queens
# 36921            3    118                  1         0     Queens
# 36922            3      0                  0         0      Bronx
#
#           neighbourhood        room_type
# 0               Midtown  Entire home/apt
# 1               Midtown  Entire home/apt
# 2               Midtown  Entire home/apt
# 3               Midtown  Entire home/apt
# 4               Midtown  Entire home/apt
# ...                 ...              ...
# 36918  Long Island City       Hotel room
# 36919  Long Island City       Hotel room
# 36920           Astoria       Hotel room
# 36921           Bayside       Hotel room
# 36922        Mott Haven       Hotel room
#
# [36923 rows x 12 columns]

# %%
# Count of room type by borough
roomtype_count= pd.DataFrame(merge2.groupby([ "borough", "room_type"])["borough_id"].count().reset_index())
roomtype_count
# Out:
#           borough        room_type  borough_id
# 0           Bronx  Entire home/apt         348
# 1           Bronx       Hotel room           1
# 2           Bronx     Private room         558
# 3           Bronx      Shared room          30
# 4        Brooklyn  Entire home/apt        7202
# 5        Brooklyn       Hotel room          17
# 6        Brooklyn     Private room        7001
# 7        Brooklyn      Shared room         219
# 8       Manhattan  Entire home/apt       10135
# 9       Manhattan       Hotel room         270
# 10      Manhattan     Private room        5948
# 11      Manhattan      Shared room         289
# 12         Queens  Entire home/apt        1641
# 13         Queens       Hotel room           9
# 14         Queens     Private room        2841
# 15         Queens      Shared room         138
# 16  Staten Island  Entire home/apt         144
# 17  Staten Island     Private room         130
# 18  Staten Island      Shared room           2

# %%
roomtype_count.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","room_type":"Entire home\\/apt","room_Type_value":348},{"borough":"Bronx","room_type":"Hotel room","room_Type_value":1},{"borough":"Bronx","room_type":"Private room","room_Type_value":558},{"borough":"Bronx","room_type":"Shared room","room_Type_value":30},{"borough":"Brooklyn","room_type":"Entire home\\/apt","room_Type_value":7202},{"borough":"Brooklyn","room_type":"Hotel room","room_Type_value":17},{"borough":"Brooklyn","room_type":"Private room","room_Type_value":7001},{"borough":"Brooklyn","room_type":"Shared room","room_Type_value":219},{"borough":"Manhattan","room_type":"Entire home\\/apt","room_Type_value":10135},{"borough":"Manhattan","room_type":"Hotel room","room_Type_value":270},{"borough":"Manhattan","room_type":"Private room","room_Type_value":5948},{"borough":"Manhattan","room_type":"Shared room","room_Type_value":289},{"borough":"Queens","room_type":"Entire home\\/apt","room_Type_value":1641},{"borough":"Queens","room_type":"Hotel room","room_Type_value":9},{"borough":"Queens","room_type":"Private room","room_Type_value":2841},{"borough":"Queens","room_type":"Shared room","room_Type_value":138},{"borough":"Staten Island","room_type":"Entire home\\/apt","room_Type_value":144},{"borough":"Staten Island","room_type":"Private room","room_Type_value":130},{"borough":"Staten Island","room_type":"Shared room","room_Type_value":2}]'

# %% [markdown]
# ## Bar Chart ##

# %%
review_breakdown = merge1[['borough', 'neighbourhood','number_of_reviews']]
review_breakdown
# Out:
#          borough neighbourhood  number_of_reviews
# 0      Manhattan       Midtown                 48
# 1      Manhattan       Midtown                474
# 2      Manhattan       Midtown                 82
# 3      Manhattan       Midtown                 92
# 4      Manhattan       Midtown                145
# ...          ...           ...                ...
# 36918      Bronx      Van Nest                  0
# 36919      Bronx   Castle Hill                 53
# 36920      Bronx   Castle Hill                 75
# 36921      Bronx    West Farms                  1
# 36922      Bronx  Country Club                  0
#
# [36923 rows x 3 columns]

# %%
review_breakdown= pd.DataFrame(merge2.groupby([ "borough", "neighbourhood"])["number_of_reviews"].sum().reset_index())
review_breakdown
# Out:
#            borough  neighbourhood  number_of_reviews
# 0            Bronx       Allerton               2024
# 1            Bronx     Baychester                514
# 2            Bronx        Belmont                211
# 3            Bronx      Bronxdale                524
# 4            Bronx    Castle Hill                128
# ..             ...            ...                ...
# 216  Staten Island    Tottenville                 72
# 217  Staten Island  West Brighton                565
# 218  Staten Island    Westerleigh                 21
# 219  Staten Island    Willowbrook                 19
# 220  Staten Island        Woodrow                  0
#
# [221 rows x 3 columns]

# %%
review_breakdown = review_breakdown.sort_values(["borough", "number_of_reviews"], ascending = (True, False))
review_breakdown
# Out:
#            borough   neighbourhood  number_of_reviews
# 9            Bronx       Concourse               2150
# 0            Bronx        Allerton               2024
# 25           Bronx      Mott Haven               1905
# 44           Bronx       Wakefield               1827
# 47           Bronx  Williamsbridge               1460
# ..             ...             ...                ...
# 219  Staten Island     Willowbrook                 19
# 204  Staten Island    Prince's Bay                 15
# 199  Staten Island        New Dorp                 10
# 188  Staten Island  Fort Wadsworth                  0
# 220  Staten Island         Woodrow                  0
#
# [221 rows x 3 columns]

# %%
review_breakdown.to_json(orient="records")
# Out:
# '[{"borough":"Bronx","neighbourhood":"Concourse","number_of_reviews":2150},{"borough":"Bronx","neighbourhood":"Allerton","number_of_reviews":2024},{"borough":"Bronx","neighbourhood":"Mott Haven","number_of_reviews":1905},{"borough":"Bronx","neighbourhood":"Wakefield","number_of_reviews":1827},{"borough":"Bronx","neighbourhood":"Williamsbridge","number_of_reviews":1460},{"borough":"Bronx","neighbourhood":"Longwood","number_of_reviews":1350},{"borough":"Bronx","neighbourhood":"Port Morris","number_of_reviews":1114},{"borough":"Bronx","neighbourhood":"Parkchester","number_of_reviews":1074},{"borough":"Bronx","neighbourhood":"Highbridge","number_of_reviews":911},{"borough":"Bronx","neighbourhood":"Throgs Neck","number_of_reviews":909},{"borough":"Bronx","neighbourhood":"Pelham Gardens","number_of_reviews":861},{"borough":"Bronx","neighbourhood":"University Heights","number_of_reviews":827},{"borough":"Bronx","neighbourhood":"Kingsbridge","number_of_reviews":750},{"borough":"Bronx","neighbourhood":"Woodlawn","number_of_reviews":704},{"borough":"Bronx","neighbourhood":"Norwood","number_of_reviews":632},{"borough":"Bronx","neighbourhood":"Morris Heights","number_of_reviews":581},{"borough":"Bronx","neighbourhood":"City Island","number_of_reviews":563},{"borough":"Bronx","neighbourhood":"Schuylerville","number_of_reviews":559},{"borough":"Bronx","neighbourhood":"Soundview","number_of_reviews":552},{"borough":"Bronx","neighbourhood":"Mount Hope","number_of_reviews":543},{"borough":"Bronx","neighbourhood":"Bronxdale","number_of_reviews":524},{"borough":"Bronx","neighbourhood":"Baychester","number_of_reviews":514},{"borough":"Bronx","neighbourhood":"East Morrisania","number_of_reviews":499},{"borough":"Bronx","neighbourhood":"Claremont Village","number_of_reviews":457},{"borough":"Bronx","neighbourhood":"Clason Point","number_of_reviews":437},{"borough":"Bronx","neighbourhood":"Concourse Village","number_of_reviews":426},{"borough":"Bronx","neighbourhood":"Fordham","number_of_reviews":331},{"borough":"Bronx","neighbourhood":"Morris Park","number_of_reviews":306},{"borough":"Bronx","neighbourhood":"Tremont","number_of_reviews":297},{"borough":"Bronx","neighbourhood":"Edenwald","number_of_reviews":294},{"borough":"Bronx","neighbourhood":"Pelham Bay","number_of_reviews":289},{"borough":"Bronx","neighbourhood":"Hunts Point","number_of_reviews":282},{"borough":"Bronx","neighbourhood":"Unionport","number_of_reviews":281},{"borough":"Bronx","neighbourhood":"Morrisania","number_of_reviews":239},{"borough":"Bronx","neighbourhood":"Riverdale","number_of_reviews":233},{"borough":"Bronx","neighbourhood":"Westchester Square","number_of_reviews":228},{"borough":"Bronx","neighbourhood":"Eastchester","number_of_reviews":222},{"borough":"Bronx","neighbourhood":"Van Nest","number_of_reviews":222},{"borough":"Bronx","neighbourhood":"Belmont","number_of_reviews":211},{"borough":"Bronx","neighbourhood":"Fieldston","number_of_reviews":183},{"borough":"Bronx","neighbourhood":"Melrose","number_of_reviews":159},{"borough":"Bronx","neighbourhood":"Castle Hill","number_of_reviews":128},{"borough":"Bronx","neighbourhood":"Spuyten Duyvil","number_of_reviews":82},{"borough":"Bronx","neighbourhood":"Olinville","number_of_reviews":80},{"borough":"Bronx","neighbourhood":"Co-op City","number_of_reviews":54},{"borough":"Bronx","neighbourhood":"North Riverdale","number_of_reviews":20},{"borough":"Bronx","neighbourhood":"Mount Eden","number_of_reviews":8},{"borough":"Bronx","neighbourhood":"West Farms","number_of_reviews":1},{"borough":"Bronx","neighbourhood":"Country Club","number_of_reviews":0},{"borough":"Brooklyn","neighbourhood":"Bedford-Stuyvesant","number_of_reviews":84320},{"borough":"Brooklyn","neighbourhood":"Williamsburg","number_of_reviews":56473},{"borough":"Brooklyn","neighbourhood":"Bushwick","number_of_reviews":34206},{"borough":"Brooklyn","neighbourhood":"Crown Heights","number_of_reviews":27131},{"borough":"Brooklyn","neighbourhood":"Greenpoint","number_of ...

# %% [markdown]
# ## Bubble Chart ##

# %%
merge2
# Out:
#              id  neighborhood_id  borough_id  latitude  longitude  \
# 0          2595              115           3  40.75362   -73.9838
# 1         59855              115           3  40.75890   -73.9699
# 2         61509              115           3  40.75749   -73.9690
# 3        235951              115           3  40.75348   -73.9707
# 4        271694              115           3  40.75282   -73.9732
# ...         ...              ...         ...       ...        ...
# 36918  35540417              165           4  40.75331   -73.9350
# 36919  38481169              165           4  40.75331   -73.9350
# 36920  15974141              131           4  40.76839   -73.9311
# 36921  35904939              132           4  40.76273   -73.7604
# 36922  42065563               26           1  40.81513   -73.9160
#
#        roomtype_id  price  number_of_reviews superhost    borough  \
# 0                1    175                 48         0  Manhattan
# 1                1    250                 82         1  Manhattan
# 2                1    110                 92         0  Manhattan
# 3                1    125                145         1  Manhattan
# 4                1    125                 19         0  Manhattan
# ...            ...    ...                ...       ...        ...
# 36918            3    150                 17         0     Queens
# 36919            3    120                  8         0     Queens
# 36920            3    100                  1         0     Queens
# 36921            3    118                  1         0     Queens
# 36922            3      0                  0         0      Bronx
#
#           neighbourhood        room_type
# 0               Midtown  Entire home/apt
# 1               Midtown  Entire home/apt
# 2               Midtown  Entire home/apt
# 3               Midtown  Entire home/apt
# 4               Midtown  Entire home/apt
# ...                 ...              ...
# 36918  Long Island City       Hotel room
# 36919  Long Island City       Hotel room
# 36920           Astoria       Hotel room
# 36921           Bayside       Hotel room
# 36922        Mott Haven       Hotel room
#
# [36923 rows x 12 columns]

# %%
# Count of room type by borough

superhost_count= pd.DataFrame(merge2.groupby(["borough", "neighbourhood"])["superhost"].sum().reset_index())
superhost_count
# Out:
#            borough  neighbourhood                        superhost
# 0            Bronx       Allerton  1000010010000000000000000111000
# 1            Bronx     Baychester                   00100000010011
# 2            Bronx        Belmont                 0000000000010000
# 3            Bronx      Bronxdale              0000000100000100011
# 4            Bronx    Castle Hill                               11
# ..             ...            ...                              ...
# 216  Staten Island    Tottenville                                1
# 217  Staten Island  West Brighton               010011000011101000
# 218  Staten Island    Westerleigh                              010
# 219  Staten Island    Willowbrook                                0
# 220  Staten Island        Woodrow                                0
#
# [221 rows x 3 columns]

# %%
superhost_count.to_csv("superhost_count.csv")

# %%
superhost_count.dtypes
# Out:
# borough          object
# neighbourhood    object
# superhost        object
# dtype: object

# %%
superhost_count['superhost'] = superhost_count['superhost'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-77-f8de941ad17f> in <module>
# ----> 1 superhost_count['superhost'] = superhost_count['superhost'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# OverflowError: Python int too large to convert to C long

# %%
# Count of room type by borough

superhost_count= pd.DataFrame(merge2.groupby(["borough", "neighbourhood"])["superhost"].sum().reset_index())
superhost_count
# Out:
#            borough  neighbourhood                        superhost
# 0            Bronx       Allerton  1000010010000000000000000111000
# 1            Bronx     Baychester                   00100000010011
# 2            Bronx        Belmont                 0000000000010000
# 3            Bronx      Bronxdale              0000000100000100011
# 4            Bronx    Castle Hill                               11
# ..             ...            ...                              ...
# 216  Staten Island    Tottenville                                1
# 217  Staten Island  West Brighton               010011000011101000
# 218  Staten Island    Westerleigh                              010
# 219  Staten Island    Willowbrook                                0
# 220  Staten Island        Woodrow                                0
#
# [221 rows x 3 columns]

# %%
superhost_count = superhost_count.sort_values(["borough", "superhost"], ascending = (True, False))
superhost_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-7c14e441bf4e> in <module>
# ----> 1 superhost_count = superhost_count.sort_values(["borough", "superhost"], ascending = (True, False))
#       2 superhost_count
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# -> 4920             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4921             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4922             indexer = ensure_platform_int(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4918             from pandas.core.sorting import lexsort_indexer
#    4919
# -> 4920             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    4921             indexer = lexsort_indexer(keys, orders=ascending, na_position=na_position)
#    4922             indexer = ensure_platform_int(indexer)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'superhost'
